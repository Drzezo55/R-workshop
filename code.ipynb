# %%
library(readxl)
library(dmetar)
library(meta)
# Out:
# Loading required package: metadat
# Loading 'meta' package (version 8.2-1).
# Type 'help(meta)' for a brief overview.

# %%
df <- read_excel("data.xlsx")

# %%
m.bin <- metabin(event.e = event.e, 
                 n.e = n.e,
                 event.c = event.c,
                 n.c = n.c,
                 studlab = author,
                 data = df,
                 sm = "RR",
                 method = "MH",
                 MH.exact = TRUE,
                 fixed = TRUE,
                 random = FALSE,
                 method.tau = "PM",
                 method.random.ci = "HK",
                 title = "Depression and Mortality")
summary(m.bin)
# Out:
# Warning message:
# Use argument 'common' instead of 'fixed' (deprecated).
# Review:     Depression and Mortality
#
#               RR           95%-CI %W(common)
# Awad 2000 1.0000 [0.6930; 1.4429]        2.1
# Awad 2001 1.0000 [0.7669; 1.3039]        4.0
# Awad 2002 1.0000 [0.7971; 1.2546]        5.5
# Awad 2003 1.0000 [0.8158; 1.2259]        6.9
# Awad 2004 1.0000 [0.8292; 1.2059]        8.1
# Awad 2005 1.0000 [0.8397; 1.1908]        9.3
# Awad 2006 1.0000 [0.8483; 1.1788]       10.5
# Awad 2007 1.0000 [0.8555; 1.1689]       11.7
# Awad 2008 1.0000 [0.8617; 1.1605]       12.8
# Awad 2009 1.0000 [0.8671; 1.1533]       14.0
# Awad 2010 1.0000 [0.8718; 1.1470]       15.1
#
# Number of studies: k = 11
# Number of observations: o = 5940 (o.e = 2200, o.c = 3740)
# Number of events: e = 2970
#
#                         RR           95%-CI    z p-value
# Common effect model 1.0000 [0.9481; 1.0548] 0.00  1.0000
#
# Quantifying heterogeneity (with 95%-CIs):
#  tau^2 = 0; tau = 0; I^2 = 0.0% [0.0%; 60.2%]; H = 1.00 [1.00; 1.59]
#
# Test of heterogeneity:
#     Q d.f. p-value
#  0.00   10  1.0000
#
# Details of meta-analysis methods:
# - Exact Mantel-Haenszel method
# - Paule-Mandel estimator for tau^2
# - Calculation of I^2 based on Q

# %%
png(file = "forestplot.png", width = 2800, height = 2400, res = 300)

meta::forest(m.bin, 
             sortvar = TE,
             prediction = TRUE, test.overall = TRUE, 
             print.tau2 = FALSE, label.e = "Music", label.c = "control",
             type.study = "circle", col.diamond = "green", col.study = "orange")

dev.off()
# Out:
# .ark.graphics.device
#                    2

# %%
loo <- metainf(m.bin)
png(file = "forestplot_loo.png", width = 2800, height = 2400, res = 300)
meta::forest(loo, col = "blue", col.diamond = "red", type = "circle")
dev.off()

# %%
rmarkdown::render("your_notebook.Rmd", output_format = "pdf_document")
